# %% [markdown]
# ***

# %%
import numpy as np
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from nltk.tokenize import WordPunctTokenizer
import warnings
warnings.filterwarnings('ignore')

# %%
# Open Reduced JSON files 
business_df = pd.read_json('yelp_dataset/TX_restaurants.json')
reviews_df = pd.read_json('yelp_dataset/TX_reviews.json')
users_df = pd.read_json('yelp_dataset/TX_users.json')
print('Total number of business: ', len(business_df))
print('Total number of reviews: ', len(reviews_df))
print('Total number of users: ', len(users_df))
# Out:
# Total number of business:  3270
# Total number of reviews:  62936
# Total number of users:  798

# %%
business_df.head(3)

# %%
reviews_df.head(3)

# %%
users_df.head(3)

# %%
# Select onlt User ID, Restaurant ID & Text from the TX Reviews dataset.
reviews_Rdf = reviews_df[['business_id', 'user_id', 'stars', 'text']]
import string
from nltk.corpus import stopwords
stop = []
for word in stopwords.words('english'):
    s = [char for char in word if char not in string.punctuation]
    stop.append(''.join(s))
reviews_Rdf.head(3)
# Out:
#               business_id                 user_id  stars  \
# 0  75HV-KqCtn_oHeiLiGlO_w  wJHy7ZJG_EvLFQDRms5rXQ      4
# 1  mrABhBpFvXTFrLiLiz286g  HHEXgBRDdkFSiDu1gDSdKg      4
# 2  dQ80ktWSRj5UIk96bRUmWw  QdhsBITt2VqQzwNxRu4QjQ      4
#
#                                                 text
# 0  Great place... delicious tapas and very nice w...
# 1  "I overheard you are out of the roast beef, ri...
# 2  We thought about going over to Brodie Oaks to ...

# %% [markdown]
# ### Function to clean the reviews text.

# %%
def cleaning_text(mess):
    revmovePunctuation = [char for char in mess if char not in string.punctuation]
    revmovePunctuation = ''.join(revmovePunctuation)
    
    # Remove all stopwords
    return " ".join([word for word in revmovePunctuation.split() if word.lower() not in stop])
reviews_Rdf['text'] = reviews_Rdf['text'].apply(cleaning_text)

# %%
# Subsets DataFrames from the Original Reviews DataFrame. 
# 1) Users with Text. (62936 rows × 2 columns)
# 2) Business with text. (62936 rows × 2 columns)
user_text = reviews_Rdf[['user_id','text']]
business_text = reviews_Rdf[['business_id', 'text']]

# %%
# Check the DataFrame Users ID with Text.
user_text.head(2)
# Out:
#                   user_id                                               text
# 0  wJHy7ZJG_EvLFQDRms5rXQ  Great place delicious tapas nice wine list try...
# 1  HHEXgBRDdkFSiDu1gDSdKg  overheard roast beef right Yes still make anot...

# %%
# Check the DataFrame Users ID with Text 
business_text.head(2)
# Out:
#               business_id                                               text
# 0  75HV-KqCtn_oHeiLiGlO_w  Great place delicious tapas nice wine list try...
# 1  mrABhBpFvXTFrLiLiz286g  overheard roast beef right Yes still make anot...

# %%
# Check all reviews from only One User 'QdhsBITt2VqQzwNxRu4QjQ'.

user_text[user_text['user_id']=='-OGWTHZng0QNhvc8dhIjyQ']['text']
# Out:
# 1980     One favorite sushi spots Austin Never crowded ...
# 2830     3 12 Stars pretty good loved atmosphere waitre...
# 3582     Im love Thai Cuisine 5 reasons 1 Amazing pad t...
# 4466     feeling Ill back many many happy hours 47 pm d...
# 4765     happened place Several years ago Zen staple wa...
# 5914     first place go return Austin town 888 Since 2 ...
# 10218    first highend Austin sushi restaurant Ive sinc...
# 10588    go Pluckers know going get Consistently OK foo...
# 11520    Eh alright gotten sushi lunch specials go conv...
# 12051    lived Austin 3 12 years never Torchys Boy mist...
# 12698    Kome favorite restaurant Ive actually waited m...
# 16043    Possibly best bakery Austin croissants muffins...
# 16727    Thank god Yelp cant believe actually consideri...
# 16847    Epoch rocks 24 hour free wifi plenty seating g...
# 17707    agree people complained location almost parkin...
# 18618    Ive actually fried avocado taco restaurant bum...
# 24102    hate write 1 star review Veggie Heaven used on...
# 25930    first tried Home Slice year ago got slice wind...
# 26685    would never come restaurant like Asia Cafe wit...
# 29862    First strike website menus found online outdat...
# 29871    Galaxy Cafe kind place order right thing good ...
# 30682    went Kenichi tonight Sunday evening happy hour...
# 30899    Let say nothing food Hudsons Bend courtesy Gro...
# 36479    Woo always love finding new place enjoy great ...
# 36494    sushi service good bathroom absolutely disgust...
# 41318    Great 24hour coffee shop full menu healthy opt...
# 43311    CARBS Oh Sweetish Hill love yet resent thee Le...
# 43322    realized reviewed Maki yet despite fact Ive pr...
# 43651    Unfortunately seems like quality ingredients c...
# 43974    Bumping review 4 stars Jardin Corona staple ea...
# 44487    Ill keep concise since many reviews already No...
# 47170    Amazing selection pastries really low prices E...
# 48350    Eh bother Lucys inconsistent Tonight ordered f...
# 48587    Cru reminds quite bit Taverna similar decor la...
# 48776    thank Terrible sushi questionable origin marga...
# 49063    went first time tonight Wednesday night 8 pm I...
# 49341    Perfectly fine couple drinks happy hour alread...
# 54344    Ive NXNW twice lunch lemon shrimp linguine rec...
# 54473    Restaurant way way small line door give go som...
# 54489    Im love Café Java really want give 5 stars pri...
# 54714    sucks give Madras Pavilion poor review first e...
# 55053    actually never heard ofnoticed place despite f...
# 55380    Apothecary one favorite finds service really f...
# 57418    Best veggie burger Austin waitstaff freaking a...
# 59476    Friend brought couple rolls via takeout Dynomi...
# 59544    Came friend 6 pm Monday reservation necessary ...
# 60189    place screams Austin hipster cool modern hipst...
# 60409    Vivos okay enjoy atmosphere theres cool patio ...
# 60596    think Ive figured got name Blue Star Cafeteria...
# 62359    Loved coconut sticky rice fresh mango slices s...
# 62444    always order blue corn stacked chicken enchila...
# Name: text, dtype: object

# %%
a= user_text[user_text['user_id']=='-OGWTHZng0QNhvc8dhIjyQ']['text']
a.count()
# Out:
# 51

# %%
# Compile All corresponding Reviews to each User and to each Business.
user_text = user_text.groupby('user_id').agg({'text': ' '.join})
business_text = business_text.groupby('business_id').agg({'text': ' '.join})

# %%
# Combine review of User 'QdhsBITt2VqQzwNxRu4QjQ'

user_text.loc['-OGWTHZng0QNhvc8dhIjyQ']['text']
# Out:
# 'One favorite sushi spots Austin Never crowded casual elegant environment fantastic sushi always great specials new fish try Happy hour amazing menu enormous even wifi 3 12 Stars pretty good loved atmosphere waitress seemed fake annoying food alright blow away go back Id rather try something else Im love Thai Cuisine 5 reasons 1 Amazing pad thai 2 Fantastic soups try tom ya 3 Nice people fast service good takeout experience 4 good Asian food within miles NW Austin 5 FREE LUNCH APPETIZER BAR 795 lunch entree Folks place may best lunch deal around unfortunate time partake wondrous smorgasbord offerings rare elusive day Im actually vacation usually take entire entree home gorging cream cheese wontons soup spring rolls salad bar yummy hard boiled eggs best peanut saucedressing town Lather negative thing enjoy spicy chicken stirfry would suggest sticking noodles soups curries specialty items feeling Ill back many many happy hours 47 pm daily 4 salads reducedprice appetizers awesome drink specials particularly enjoyed 6 huckleberry swirled frozen margaritas companion also loved lemon drop martini 5 wine glass 3 kinds 5 mojitos 5 martinis w gin vodka moreIm happy drinker grabbed table loungebar area Sunday night 6 pm half full think waiter new nice cute even look couple minutes get second round drinks decided order bunch appetizers happy hour menu Tortilla soup tomatoy taste reminded chili base prefer broth enjoyed presentation guacamole chicken good probably order Guac queso loved queso chips good many onions guacwhy people avocados Field greens salad w candied walnuts goat cheese delicious Fried avocado topped w crab meat remoulade pretty dang good Tuna tartare w mango avocado meh impressed think ordered way many things avocado swear menu makes Thank god go green chili mac cheese think end meal feeling ready give birth interior quite nice bit generic moderndesign fashion Jaspers new American type places dark see lake Id like come back weather nice 3 12 stars happened place Several years ago Zen staple wanted healthy flavorful affordable quick food clean environment Fast forward gone way downhill flavor department ordered Build Bowl udon noodles spicy teriyaki chicken breast carrots broccoli onions mushrooms noodles finebut sauce bland unforgivable painfully obvious vegetables chicken steamedcooked separately thrown top pile sauced noodles like eating one frozen bags veggies plus undercooked top added barely cooked water chestnuts ask guys better first place go return Austin town 888 Since 2 blocks apartment many late college night made complete sesame tofu pad thai yellow curry open even later til 2 every day guess finally got clue stoners eat dinner midnight people think Wanfu disgusting barrierbreaking vietnamese reliable tasty comfort food get 5 stars offer brown rice first highend Austin sushi restaurant Ive since Kenichi really count Texas Road Kill roll incredible Ive never anything like like spicy things must get also beautiful multicolored smelt roe top fatty salmon marinated tuna nigiri great spider roll evo tempurabattered good felt sauce accompanying bit lacking think eel sauce better sauce spider rolls maybe thats menu large anyone could find something eat arrived Saturday restaurant opening 530 645 place almost full COMPLETELY blown away real deal folks doubt gets better Musashino Austin waitress extremely friendly 5 rolls salad miso 2 nigiri came 67 tip Id go back often money go Pluckers know going get Consistently OK food OK service word caution like spicy food went Hot Buffalo flavor wings HOLY MOTHER PEARL cant believe people calling spicy wings weak Maybe got fluke batch hottest things ever eaten lips literally burning every time took bite companions noted fact beginning sweat tear Thank god blue cheese sauce save day would never come coworkers like come lunch block office kind go along think food bit overpriced lunch specials 799 chicken Thats special price Eh alright gotten sushi lunch specials go convenient tex ...

# %% [markdown]
# ### Vectorization with Term Frequency Inverse Doc. Frequency (TF-IDF) to extract the features from the text.

# %%
# Sparse Matrix User Text vectorizer (798 x 5000 )
user_vectorizer = TfidfVectorizer(tokenizer = WordPunctTokenizer().tokenize, max_features=5000)
user_vectors = user_vectorizer.fit_transform(user_text['text'])

# Sparse mMtrix Business Text vectorizer (779 x 5000)
business_vectorizer = TfidfVectorizer(tokenizer = WordPunctTokenizer().tokenize, max_features=5000)
business_vectors = business_vectorizer.fit_transform(business_text['text'])

# %% [markdown]
# ### Users / Businesses with Stars Matrix.

# %%
user_bussiness_stars = pd.pivot_table(reviews_Rdf, values='stars', index=['user_id'], columns=['business_id'])
user_bussiness_stars
# Out:
# business_id             -4ofMtrD7pSpZIX5pnDkig  -85pDrVcAdzNK55bFpintg  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN
# zx8hZcEiqwLnPJWSsblyzA                     4.0                     NaN
#
# business_id             -BBSLCjzw3i2PHuwJ_dabA  -Ce8p148xb0-4dv_3zwm3A  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     2.0                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     5.0
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             -WA4tNsXZq5sxcGw8a5_IQ  -_GnwXmzC3DXsHR9nyaC2g  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     1.0
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     3.5                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     2.0
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             -jQOsyXnAMKu6ND7ongXFg  -qjkQHH-5O8BAztc6udOuw  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     5.0
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             -waa6lH9SmAkaKiLx74_FA  0-Y_m4TJZufHBVozbMOqbA  ...  \
# user_id                                                                 ...
# -0MQ4webH2uc1ZAsGsNENg                     4.0                     2.0  ...
# -2sNTzGyci98Mp9PmPRg8w                     2.0                     NaN  ...
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN  ...
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN  ...
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN  ...
# ...                                        ...                     ...  ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN  ...
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     5.0  ...
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN  ...
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN  ...
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN  ...
#
# business_id             z3JW-nsdfC8ijst_PSeMIA  z4fQL2IHUR4ENonH7A_9tQ  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     2.0
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             zDVjN3dC9EfQno21m3O8Pg  zE0EGIsOdAO83xE3CypN-A  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             zFaHweOJ40jjtvpGTjlspw  zM98ZSIJyuBQabyYornLpw  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     5.0                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     5.0                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             zVILoCmmDSgcM5bc2BKVWg  zZIWHmITwqaC8OhnPkjEIQ  \
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     NaN
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     NaN
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# business_id             zerPYZ-lid5CG27a1-7YMw  zyHMtStYlKG67WRprp6GZQ
# user_id
# -0MQ4webH2uc1ZAsGsNENg                     NaN                     NaN
# -2sNTzGyci98Mp9PmPRg8w                     NaN                     3.0
# -4RH83ibNRpwj8NlBwtMdQ                     NaN                     NaN
# -8QoOIfvwwxJ4sY201WP5A                     NaN                     NaN
# -OGWTHZng0QNhvc8dhIjyQ                     NaN                     NaN
# ...                                        ...                     ...
# zgLUWGBKrSoIIH3E2XLvNQ                     NaN                     NaN
# zlL_PbFTXjrGXhTbPsjmlQ                     NaN                     NaN
# zonT-KQFJiejFNUrs2KR0Q                     NaN                     NaN
# zqMc0O7vDj82Sz5Fler1EA                     NaN                     4.0
# zx8hZcEiqwLnPJWSsblyzA                     NaN                     NaN
#
# [798 rows x 779 columns]

# %%
P = pd.DataFrame(user_vectors.toarray(), index=user_text.index, columns=user_vectorizer.get_feature_names())
Q = pd.DataFrame(business_vectors.toarray(), index=business_text.index, columns=business_vectorizer.get_feature_names())

# %%
P.shape, Q.shape
# Out:
# ((798, 5000), (779, 5000))

# %%
P.head(2)

# %%
Q.head(2)

# %%
def matrix_factorization(R, P, Q, steps=50, gamma=0.001,lamda=0.02):
    for step in range(steps):
        for i in R.index:
            for j in R.columns:
                if R.loc[i,j]>0:
                    eij=R.loc[i,j]-np.dot(P.loc[i],Q.loc[j])
                    P.loc[i]=P.loc[i]+gamma*(eij*Q.loc[j]-lamda*P.loc[i])
                    Q.loc[j]=Q.loc[j]+gamma*(eij*P.loc[i]-lamda*Q.loc[j])
        e=0
        for i in R.index:
            for j in R.columns:
                if R.loc[i,j]>0:
                    e= e + pow(R.loc[i,j]-np.dot(P.loc[i],Q.loc[j]),2)+lamda*(pow(np.linalg.norm(P.loc[i]),2)+pow(np.linalg.norm(Q.loc[j]),2))
        if e<0.001:
            break
        
    return P,Q

# %% [markdown]
# * Takes __23 min 55s__ with the following parameters: __Steps = 05, gamma = 0.020 ,lamda=0.02__
# * Takes __35 min 14s__ with the following parameters: __Steps = 10, gamma = 0.020 ,lamda=0.02__
# * Takes __50 min 25s__ with the following parameters: __Steps = 25, gamma = 0.001 ,lamda=0.02__

# %% [markdown]
# ### To Train New Data ONLY

# %%
#%%time
#P, Q = matrix_factorization(user_bussiness_stars, P, Q, steps=25, gamma=0.001,lamda=0.02)

# %%
# STORE P, Q and vectorizer in pickle file
import pickle
output = open('yelp_dataset/yelp_recommendation_model_LFM_v3.pkl', 'wb')
pickle.dump(P,output)
pickle.dump(Q,output)
pickle.dump(user_vectorizer,output)
output.close()

# %% [markdown]
# ### To OPEN saved Model

# %%
# LOAD P, Q and vectorizer in pickle file
import pickle
input = open('yelp_dataset/yelp_recommendation_model_LFM_v3.pkl','rb')
P = pickle.load(input)
Q = pickle.load(input)
userid_vectorizer = pickle.load(input)
input.close()

# %% [markdown]
# ### Testing the Moded:
# * Input: Preferences in Text form.
# * Output: Top Five Recommendations.

# %%
words = "Best sushi, lemon aioli"
test_df= pd.DataFrame([words], columns=['text'])
test_df['text'] = test_df['text'].apply(cleaning_text)
test_vectors = userid_vectorizer.transform(test_df['text'])
test_v_df = pd.DataFrame(test_vectors.toarray(), index=test_df.index, columns=userid_vectorizer.get_feature_names())

predictItemRating=pd.DataFrame(np.dot(test_v_df.loc[0],Q.T),index=Q.index,columns=['Rating'])
topRecommendations=pd.DataFrame.sort_values(predictItemRating,['Rating'],ascending=[0])[:5]

for i in topRecommendations.index:
    print(business_df[business_df['business_id']==i]['name'].iloc[0])
    print(business_df[business_df['business_id']==i]['categories'].iloc[0])
    print(str(business_df[business_df['business_id']==i]['stars'].iloc[0])+ ' '+str(business_df[business_df['business_id']==i]['review_count'].iloc[0]))
    print('')
# Out:
# Bess Bistro
# Cajun/Creole, Southern, Restaurants, American (New), French
# 3.5 520
#
# Ego's
# Dive Bars, Nightlife, Lounges, Karaoke, Bars, Pizza, Restaurants
# 3.5 249
#
# Austin Diner
# Restaurants, Diners
# 3.0 288
#
# The Common Interest
# Karaoke, American (New), American (Traditional), Nightlife, Sports Bars, Restaurants, Bars
# 4.0 157
#
# Eberly
# Restaurants, Breakfast & Brunch, Nightlife, Bars, Pubs, American (Traditional)
# 4.0 467

# %%
"""
Getting user_id and most relevant info for Kevan (Kevan is Not on users_train Set.)
"""
user_X = users_df[users_df['name']=='Kevan']
user_X
# Out:
#                     user_id   name  review_count        yelping_since  useful  \
# 473  -OGWTHZng0QNhvc8dhIjyQ  Kevan           197  2007-07-14 17:16:27     329
#
#      funny  cool                          elite  \
# 473     85    97  2011,2012,2015,2016,2017,2018
#
#                                                friends  fans  ...  \
# 473  s8nkbQAlrVPfg1u4anGKtw, o4ZZnp8ugpfhzLAa6jFenA...     4  ...
#
#      compliment_more  compliment_profile  compliment_cute  compliment_list  \
# 473                5                   0                0                0
#
#      compliment_note  compliment_plain  compliment_cool  compliment_funny  \
# 473                6                11                6                 6
#
#      compliment_writer  compliment_photos
# 473                  3                  2
#
# [1 rows x 22 columns]

# %% [markdown]
# ***
